# %%
import torch 
import torch.nn as nn
import numpy as np
from torch.utils.data.sampler import SubsetRandomSampler

# %%
""""
 try to train the model, plot some loss curves for training and testing losses, and report your accuracy! 
 As it's set right now, I think that 100% accuracy should be manageable. 
 Try adding some noise to the time series one you see nice curves. 
 Show the results from all of these experiments and let's see how it goes!
"""

class SimpleSignal(torch.utils.data.Dataset):
    def __init__(self, N=1000, T=100):
        super(SimpleSignal, self).__init__()
        self.N = N
        self.T = T
        self.data, self.labels = self.generate_data()
        self.train_ix, self.test_ix = self.get_ix_splits()
    
    def __getitem__(self, ix):
        return self.data[ix], self.labels[ix]
    
    def __len__(self):
        return len(self.data)

    def get_ix_splits(self):
        split_props = [0.8, 0.1, 0.1] # Train/validation/test split proportions
        indices = range(len(self.data))
        split_points = [int(len(self.data)*i) for i in split_props]
        train_ix = np.random.choice(indices,
                                    split_points[0],
                                    replace=False)
        test_ix = np.random.choice((list(set(indices)-set(train_ix))),
                                    split_points[1],
                                    replace=False)
        return train_ix, test_ix

    def generate_data(self):
        N_pos = int(self.N/2)
        N_neg = int(self.N/2)
        data = [] 
        labels = [] 
        for i in range(N_pos + N_neg):
            time_series = np.zeros(self.T)
            time_series = np.random.normal(0, .3, self.T) 
# You can make the task harder if you raise the standard deviation of the noise
            if i < N_pos:
                labels.append(0)
            else:
                time_series[np.random.choice(self.T)] = 1 # Put the signal at a random place
                labels.append(1)
            data.append(time_series)
            
        # --- shuffle the data ---
        permutation = np.random.choice(len(data), len(data), replace=False).astype(int)
        data = [data[i] for i in permutation]
        labels = [labels[i] for i in permutation]
        return torch.tensor(data, dtype=torch.float).unsqueeze(2), torch.tensor(labels, dtype=torch.long)

# %%
HIDDEN_DIMENSION_vector = [5, 10, 20, 40]
N_LAYERS = 1
BATCH_SIZE = 10
N_EPOCHS = 20
LEARNING_RATE = .001
SEQ_LENGTH = 10     #of data
N_INSTANCES = 1000  #of data
N_FEATURES = 1      #dimensions of each input?
N_CLASSES = 2       #dimensions of each output?

# --- create the dataset ---
data = SimpleSignal(T=SEQ_LENGTH, N=N_INSTANCES)
#for i in range(data.N):
    #print(data.data[i], data.labels[i])

# %%
# --- define the data loaders ---
train_sampler = SubsetRandomSampler(data.train_ix) # Random sampler for training indices
test_sampler = SubsetRandomSampler(data.test_ix) # Random sampler for testing indices

train_loader = torch.utils.data.DataLoader(dataset=data,
                                           batch_size=BATCH_SIZE, 
                                           sampler=train_sampler,
                                           shuffle=False)

test_loader = torch.utils.data.DataLoader(dataset=data,
                                          batch_size=BATCH_SIZE, 
                                          sampler=test_sampler,
                                          shuffle=False)

# --- define your model here ---
class RNN(nn.Module):
    def __init__(self, HIDDEN_DIMENSION, N_CLASSES, N_FEATURES, N_LAYERS, BATCH_SIZE):
        super(RNN, self).__init__()
        self.N_LAYERS = N_LAYERS
        self.BATCH_SIZE = BATCH_SIZE
        self.HIDDEN_DIMENSION = HIDDEN_DIMENSION
        self.N_CLASSES = N_CLASSES
        
        # --- define mappings here ---
        self.lstm = torch.nn.LSTM(N_FEATURES, HIDDEN_DIMENSION)       #sets up initial weight matrices
        self.out = torch.nn.Linear(HIDDEN_DIMENSION, N_CLASSES)
        #nonlinear part - tells probabilites
        self.softmax = torch.nn.Softmax(dim=1)
    
    def forward(self, X):  #X is input data - tensor shape = (batch size, input dimension)
        # --- define forward pass here ---
        #initialize hidden state - need to do this because this is an RNN/LSTM (you use torch.nn.LSTM above)
        state = (torch.zeros(N_LAYERS, BATCH_SIZE, HIDDEN_DIMENSION), # h_0 initial hidden state
                 torch.zeros(N_LAYERS, BATCH_SIZE, HIDDEN_DIMENSION)) # c_0 initial cell state
        X = torch.transpose(X, 0, 1)  #should have shape timesteps, batch_size, num features
        
        hidden, state = self.lstm(X, state)   #X is timeseries, shape is (timesteps, batch size)
        #hidden = h_t = hidden cell sate after w1 weight matrix (self.LSTM has been applied to the current cell) = this is actually vector containing all h_t's for each cell
        #state = (h_n, c_n) = h_n is hidden state that depends on all previous cells, c_n is cell state that depends on all previous cells
        output = self.out(hidden[-1])   #cell's hidden state gets passed thru w2 (out) weight matrix to produce output
        prediction = self.softmax(output)
        return prediction

# %%
loss_dif_hid_dim = []
accuracy_dif_hid_dim = []
loss_testing_dif_hid_dim=[]
accuracy_testing_dif_hid_dim=[]

for i_hid_dim in range(len(HIDDEN_DIMENSION_vector)):
    # --- initialize the model and the optimizer ---
    HIDDEN_DIMENSION = HIDDEN_DIMENSION_vector[i_hid_dim]
    model = RNN(HIDDEN_DIMENSION, N_CLASSES, N_FEATURES, N_LAYERS, BATCH_SIZE)
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE) 
    # Using the Adam optimizer - don't worry about the details, it's going to update the network's weights.
    criterion = torch.nn.CrossEntropyLoss()   #definig loss function

    # --- training the model ---
    loss_vector_training=[]
    accuracy_vector_training=[]
    for epoch in range(N_EPOCHS):
        loss_sum = 0
        predictions_sum = 0
        labels_sum = 0
        for i, (time_series, labels) in enumerate(train_loader): # Iterate through the training batches
            # --- Forward pass ---
            predictions = model(time_series)   #time_series has to have shape (batch size=10, input dimension=1)
        
            # --- Compute gradients and update weights ---
            optimizer.zero_grad()   #zero gradients, can also do model.zero_grad() in this case
        
            for i in range(10):
                predict = predictions[i,1]
                if predict <=.5:
                    estimate=0
                else:
                    estimate=1
                if estimate==labels[i]:
                    predictions_sum += 1
                labels_sum += 1
            loss = criterion(predictions, labels)    #predictions shape is (10, 2), labels shape is (10)
            loss.backward(retain_graph = True)
            optimizer.step()  #updates parameters using Adam alg rather than grad descent
            loss_sum += loss.item()
            #if (i+1) % 1 == 0:
            #    print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch+1, N_EPOCHS, i+1, len(train_loader), loss.item()))
        accuracy = predictions_sum/labels_sum
        loss_total = loss_sum/80
        accuracy_vector_training.append(accuracy)
        loss_vector_training.append(loss_total)
        print('accuracy: ', accuracy)
        print ('Loss for each Epoch:','Epoch [{}/{}], Loss: {:.4f}'.format(epoch+1, N_EPOCHS, loss_total))
        
        
    # --- testing the model ---
    loss_vector_testing=[]
    accuracy_vector_testing=[]
    for i, (time_series, labels) in enumerate(test_loader): # Iterate through the testing set, 10 timeseries in 10 batches (100 timeseries total)
            predictions_sum = 0
            labels_sum = 0
            loss_sum = 0
            predictions = model(time_series)   #time_series has to have shape (batch size=10, input dimension=1)

            for i in range(10):
                predict = predictions[i,1]
                if predict <=.5:
                    estimate=0
                else:
                    estimate=1
                if estimate==labels[i]:
                    predictions_sum += 1
                labels_sum += 1
            loss = criterion(predictions, labels)    #predictions shape is (10, 2), labels shape is (10)
            loss_sum += loss.item()
            accuracy = predictions_sum/labels_sum
            loss_vector_testing.append(loss_sum)
            accuracy_vector_testing.append(accuracy)
    
    #----keeping track of all losses and accuracies for each hidden dimension
    loss_dif_hid_dim.append(loss_vector_training)
    accuracy_dif_hid_dim.append(accuracy_vector_training)
    loss_testing_dif_hid_dim.append(loss_vector_testing)
    accuracy_testing_dif_hid_dim.append(accuracy_vector_testing)
# Out:
# accuracy:  0.49125
# Loss for each Epoch: Epoch [1/20], Loss: 0.7020
# accuracy:  0.49125
# Loss for each Epoch: Epoch [2/20], Loss: 0.6992
# accuracy:  0.49125
# Loss for each Epoch: Epoch [3/20], Loss: 0.6971
# accuracy:  0.49125
# Loss for each Epoch: Epoch [4/20], Loss: 0.6956
# accuracy:  0.49125
# Loss for each Epoch: Epoch [5/20], Loss: 0.6943
# accuracy:  0.50125
# Loss for each Epoch: Epoch [6/20], Loss: 0.6933
# accuracy:  0.5525
# Loss for each Epoch: Epoch [7/20], Loss: 0.6919
# accuracy:  0.63625
# Loss for each Epoch: Epoch [8/20], Loss: 0.6864
# accuracy:  0.7025
# Loss for each Epoch: Epoch [9/20], Loss: 0.6469
# accuracy:  0.7175
# Loss for each Epoch: Epoch [10/20], Loss: 0.6034
# accuracy:  0.7525
# Loss for each Epoch: Epoch [11/20], Loss: 0.5775
# accuracy:  0.77625
# Loss for each Epoch: Epoch [12/20], Loss: 0.5576
# accuracy:  0.7825
# Loss for each Epoch: Epoch [13/20], Loss: 0.5353
# accuracy:  0.82125
# Loss for each Epoch: Epoch [14/20], Loss: 0.5157
# accuracy:  0.8375
# Loss for each Epoch: Epoch [15/20], Loss: 0.4960
# accuracy:  0.85
# Loss for each Epoch: Epoch [16/20], Loss: 0.4812
# accuracy:  0.88
# Loss for each Epoch: Epoch [17/20], Loss: 0.4631
# accuracy:  0.9
# Loss for each Epoch: Epoch [18/20], Loss: 0.4460
# accuracy:  0.89625
# Loss for each Epoch: Epoch [19/20], Loss: 0.4381
# accuracy:  0.92375
# Loss for each Epoch: Epoch [20/20], Loss: 0.4257
# accuracy:  0.50875
# Loss for each Epoch: Epoch [1/20], Loss: 0.6925
# accuracy:  0.56125
# Loss for each Epoch: Epoch [2/20], Loss: 0.6910
# accuracy:  0.65125
# Loss for each Epoch: Epoch [3/20], Loss: 0.6838
# accuracy:  0.6875
# Loss for each Epoch: Epoch [4/20], Loss: 0.6298
# accuracy:  0.7025
# Loss for each Epoch: Epoch [5/20], Loss: 0.5935
# accuracy:  0.71375
# Loss for each Epoch: Epoch [6/20], Loss: 0.5797
# accuracy:  0.73
# Loss for each Epoch: Epoch [7/20], Loss: 0.5671
# accuracy:  0.74
# Loss for each Epoch: Epoch [8/20], Loss: 0.5552
# accuracy:  0.755
# Loss for each Epoch: Epoch [9/20], Loss: 0.5416
# accuracy:  0.76875
# Loss for each Epoch: Epoch [10/20], Loss: 0.5309
# accuracy:  0.77875
# Loss for each Epoch: Epoch [11/20], Loss: 0.5176
# accuracy:  0.79875
# Loss for each Epoch: Epoch [12/20], Loss: 0.5053
# accuracy:  0.81
# Loss for each Epoch: Epoch [13/20], Loss: 0.4951
# accuracy:  0.83125
# Loss for each Epoch: Epoch [14/20], Loss: 0.4825
# accuracy:  0.845
# Loss for each Epoch: Epoch [15/20], Loss: 0.4717
# accuracy:  0.86
# Loss for each Epoch: Epoch [16/20], Loss: 0.4598
# accuracy:  0.8825
# Loss for each Epoch: Epoch [17/20], Loss: 0.4497
# accuracy:  0.89375
# Loss for each Epoch: Epoch [18/20], Loss: 0.4356
# accuracy:  0.905
# Loss for each Epoch: Epoch [19/20], Loss: 0.4241
# accuracy:  0.92125
# Loss for each Epoch: Epoch [20/20], Loss: 0.4161
# accuracy:  0.50875
# Loss for each Epoch: Epoch [1/20], Loss: 0.6930
# accuracy:  0.52375
# Loss for each Epoch: Epoch [2/20], Loss: 0.6884
# accuracy:  0.685
# Loss for each Epoch: Epoch [3/20], Loss: 0.6261
# accuracy:  0.705
# Loss for each Epoch: Epoch [4/20], Loss: 0.5944
# accuracy:  0.72125
# Loss for each Epoch: Epoch [5/20], Loss: 0.5787
# accuracy:  0.73375
# Loss for each Epoch: Epoch [6/20], Loss: 0.5641
# accuracy:  0.73875
# Loss for each Epoch: Epoch [7/20], Loss: 0.5514
# accuracy:  0.75625
# Loss for each Epoch: Epoch [8/20], Loss: 0.5409
# accuracy:  0.7825
# Loss for each Epoch: Epoch [9/20], Loss: 0.5192
# accuracy:  0.79125
# Loss for each Epoch: Epoch [10/20], Loss: 0.5120
# accuracy:  0.81375
# Loss for each Epoch: Epoch [11/20], Loss: 0.4886
# accuracy:  0.845
# Loss for each Epoch: Epoch [12/20], Loss: 0.4688
# accuracy:  0.87125
# Loss for each Epoch: Epoch [13/20], Loss: 0.4512
# accuracy:  0.88625
# Loss for each Epoch: Epoch [14/20], Loss: 0.4359
# accuracy:  0.90875
# Loss for each Epoch: Epoch [15/20], Loss: 0.4187
# accuracy:  0.92
# Loss for each Epoch: Epoch [16/20], Loss: 0.4086
# accuracy:  0.92875
# Loss for each Epoch: Epoch [17/20], Loss: 0.3997
# accuracy:  0.94125
# Loss for each Epoch: Epoch [18/20], Loss: 0.3875
# accuracy:  0.95
# Loss for each Epoch: Epoch [19/20], Loss: 0.3789
# accuracy:  0.96625
# Loss for each Epoch: Epoch [20/20], Loss: 0.3657
# accuracy:  0.51625
# Loss for each Epoch: Epoch [1/20], Loss: 0.6917
# accuracy:  0.6425
# Loss for each Epoch: Epoch [2/20], Loss: 0.6444
# accuracy:  0.6975
# Loss for each Epoch: Epoch [3/20], Loss: 0.5950
# accuracy:  0.71875
# Loss for each Epoch: Epoch [4/20], Loss: 0.5727
# accuracy:  0.745
# Loss for each Epoch: Epoch [5/20], Loss: 0.5495
# accuracy:  0.765
# Loss for each Epoch: Epoch [6/20], Loss: 0.5324
# accuracy:  0.7825
# Loss for each Epoch: Epoch [7/20], Loss: 0.5137
# accuracy:  0.8075
# Loss for each Epoch: Epoch [8/20], Loss: 0.5026
# accuracy:  0.8475
# Loss for each Epoch: Epoch [9/20], Loss: 0.4706
# accuracy:  0.89
# Loss for each Epoch: Epoch [10/20], Loss: 0.4338
# accuracy:  0.91
# Loss for each Epoch: Epoch [11/20], Loss: 0.4111
# accuracy:  0.92875
# Loss for each Epoch: Epoch [12/20], Loss: 0.3963
# accuracy:  0.94375
# Loss for each Epoch: Epoch [13/20], Loss: 0.3809
# accuracy:  0.95375
# Loss for each Epoch: Epoch [14/20], Loss: 0.3688
# accuracy:  0.96875
# Loss for each Epoch: Epoch [15/20], Loss: 0.3579
# accuracy:  0.97875
# Loss for each Epoch: Epoch [16/20], Loss: 0.3508
# accuracy:  0.98
# Loss for each Epoch: Epoch [17/20], Loss: 0.3466
# accuracy:  0.9775
# Loss for each Epoch: Epoch [18/20], Loss: 0.3467
# accuracy:  0.97875
# Loss for each Epoch: Epoch [19/20], Loss: 0.3443
# accuracy:  0.98375
# Loss for each Epoch: Epoch [20/20], Loss: 0.3378

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

epochs_vector = [i for i in range(1, 21)]
plt.plot(epochs_vector, loss_dif_hid_dim[0])
plt.plot(epochs_vector, loss_dif_hid_dim[1])
plt.plot(epochs_vector, loss_dif_hid_dim[2])
plt.plot(epochs_vector, loss_dif_hid_dim[3])
plt.legend(['5', '10', '20', '40'], loc='upper right', title="number of hidden dimensions")
plt.title('Training Data: Loss Plot')
plt.ylabel('Loss')
plt.xlabel('Epoch (1 epoch = 80 batches)')
plt.show()

plt.plot(epochs_vector, accuracy_dif_hid_dim[0])
plt.plot(epochs_vector, accuracy_dif_hid_dim[1])
plt.plot(epochs_vector, accuracy_dif_hid_dim[2])
plt.plot(epochs_vector, accuracy_dif_hid_dim[3])
plt.legend(['5', '10', '20', '40'], loc='lower right', title="number of hidden dimension")
plt.title('Training Data: Accuracy Plot')
plt.ylabel('Accuracy')
plt.xlabel('Epoch (1 epoch = 20 batches)')
plt.show()

batch_vector = [i for i in range(1, 11)]
plt.plot(batch_vector, loss_testing_dif_hid_dim[0])
plt.plot(batch_vector, loss_testing_dif_hid_dim[1])
plt.plot(batch_vector, loss_testing_dif_hid_dim[2])
plt.plot(batch_vector, loss_testing_dif_hid_dim[3])
plt.legend(['5', '10', '20', '40'], loc='upper right', title="number of hidden dimensions")
plt.title('Testing Data: Loss Plot')
plt.ylabel('Loss')
plt.xlabel('Batch (1 batch = 10 time series)')
plt.axis([0, 10, .2, .9])
plt.show()

plt.plot(batch_vector, accuracy_testing_dif_hid_dim[0])
plt.plot(batch_vector, accuracy_testing_dif_hid_dim[1])
plt.plot(batch_vector, accuracy_testing_dif_hid_dim[2])
plt.plot(batch_vector, accuracy_testing_dif_hid_dim[3])
plt.legend(['5', '10', '20', '40'], loc='lower right', title="number of hidden dimensions")
plt.title('Testing Data: Accuracy Plot')
plt.ylabel('Accuracy')
plt.xlabel('Batch (1 batch = 10 time series)')
plt.axis([0, 10, 0, 1.066])
plt.show()

# %%
print(accuracy_testing_dif_hid_dim[0])
# Out:
# [0.9, 0.9, 0.8, 0.9, 1.0, 1.0, 1.0, 0.9, 0.8, 0.9]

# %%
def truncate(n, decimals):
    multiplier = 10 ** decimals
    return int(n * multiplier) / multiplier

print('Testing Data: Average Accuracy')
print('hid dim = 5      ', truncate(np.average(accuracy_testing_dif_hid_dim[0]), 2 ) )
print('hid dim = 10     ', truncate(np.average(accuracy_testing_dif_hid_dim[1]), 2 ) )
print('hid dim = 20     ', truncate(np.average(accuracy_testing_dif_hid_dim[2]), 2 ) )
print('hid dim = 40     ', truncate(np.average(accuracy_testing_dif_hid_dim[0]), 2 ) )
# Out:
# Testing Data: Average Accuracy
# hid dim = 5       0.91
# hid dim = 10      0.9
# hid dim = 20      1.0
# hid dim = 40      0.91
